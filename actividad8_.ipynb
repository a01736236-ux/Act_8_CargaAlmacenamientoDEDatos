# %%
import json 
import pandas as pd
import numpy as np
import glob
import LibreriaJorge as Jorge
import importlib
importlib.reload(Jorge)
# Out:
# <module 'LibreriaJorge' from 'c:\\Users\\Jorge Cortés Sánchez\\Downloads\\Descargas\\Analitica\\Analitica\\Prof. Alfredo\\Carga de datos\\LibreriaJorge.py'>

# %%
df_csv= Jorge.cargar_dataset('Oporto_Portugal.csv')

# %%
df_xlsx=Jorge.cargar_dataset('Antigüedad de saldos 17.03.2023.xlsx')

# %%
df_json=Jorge.cargar_dataset('data-nl-2015.json')

# %%
df_html=Jorge.cargar_dataset('Data_Airbnb.html')

# %% [markdown]
# ***Función de Limpieza***

# %%
df_csv.isnull().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# listing_url                         0
# last_scraped                        0
# source                              0
# name                                0
# description                       348
# neighborhood_overview            6531
# picture_url                         0
# host_id                             0
# host_url                            0
# host_name                           0
# host_since                          0
# host_location                    5011
# host_about                       7056
# host_response_time               2233
# host_response_rate               2233
# host_acceptance_rate             1695
# host_is_superhost                 848
# host_thumbnail_url                  0
# host_picture_url                    0
# host_neighbourhood              13745
# host_listings_count                 0
# host_total_listings_count           0
# host_verifications                  0
# ...

# %%
# B) Sustitución de valores nulos con ffill
df_ffill = Jorge.nulos_ffill_df(df_csv)
print("Valores nulos después de ffill:")
df_ffill
#Localiza todas las celdas con valores nulos.
#Cada nulo se sustituye con el valor inmediatamente anterior en la misma columna.
#El proceso se repite en todas las columnas.
# Out:
# c:\Users\Jorge Cortés Sánchez\Downloads\Descargas\Analitica\Analitica\Prof. Alfredo\Carga de datos\LibreriaJorge.py:29: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")
# Valores nulos después de ffill:
#        Unnamed: 0                   id  \
# 0               0                41339
# 1               1                55111
# 2               2                73828
# 3               3                87873
# 4               4                94701
# ...           ...                  ...
# 14868       14868  1442944169953064519
# 14869       14869  1442949312063381006
# 14870       14870  1442972095274896534
# 14871       14871  1443457123327763296
# 14872       14872  1443457546151071185
#
#                                             listing_url last_scraped  \
# 0                    https://www.airbnb.com/rooms/41339   2025-06-28
# ...

# %%
# C) Sustitución de valores nulos con bfill
df_bfill = Jorge.nulos_bfill_df(df_csv)
print("Valores nulos después de bfill:")
df_bfill
#Localiza todas las celdas con valores nulos.
#Cada nulo se sustituye con el valor inmediatamente siguiente en la misma columna.
#El proceso se repite en todas las columnas.
# Out:
# c:\Users\Jorge Cortés Sánchez\Downloads\Descargas\Analitica\Analitica\Prof. Alfredo\Carga de datos\LibreriaJorge.py:37: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="bfill")
# Valores nulos después de bfill:
#        Unnamed: 0                   id  \
# 0               0                41339
# 1               1                55111
# 2               2                73828
# 3               3                87873
# 4               4                94701
# ...           ...                  ...
# 14868       14868  1442944169953064519
# 14869       14869  1442949312063381006
# 14870       14870  1442972095274896534
# 14871       14871  1443457123327763296
# 14872       14872  1443457546151071185
#
#                                             listing_url last_scraped  \
# 0                    https://www.airbnb.com/rooms/41339   2025-06-28
# ...

# %%
# D) Sustitución de valores nulos con un string concreto (solo variables tipo string)
df_string = Jorge.nulos_string_df(df_csv)
print("Valores nulos después de reemplazar en strings:")
df_string
#Identifica las columnas con datos de tipo texto (object).
#Reemplaza los valores nulos de esas columnas por un texto fijo (ejemplo: "sin_registro").
# Out:
# Valores nulos después de reemplazar en strings:
#        Unnamed: 0                   id    host_id  host_listings_count  \
# 0               0                41339     180050                   26
# 1               1                55111     259711                    3
# 2               2                73828     259711                    3
# 3               3                87873     480980                    4
# 4               4                94701     505473                    1
# ...           ...                  ...        ...                  ...
# 14868       14868  1442944169953064519  695687907                    3
# 14869       14869  1442949312063381006  695687907                    3
# 14870       14870  1442972095274896534  110938864                    2
# 14871       14871  1443457123327763296  452918929                  114
# 14872       14872  1443457546151071185  452918929                  114
#
# ...

# %%
# E) Sustitución de valores nulos con promedio (solo numéricas)
df_limpio= Jorge.nulos_prom_df(df_csv)
df_limpio
#Identifica las columnas con datos numéricos (int, float).
#Calcula el promedio de cada columna.
#Reemplaza los valores nulos de esa columna con su promedio.
# Out:
#        Unnamed: 0                   id    host_id  host_listings_count  \
# 0               0                41339     180050                   26
# 1               1                55111     259711                    3
# 2               2                73828     259711                    3
# 3               3                87873     480980                    4
# 4               4                94701     505473                    1
# ...           ...                  ...        ...                  ...
# 14868       14868  1442944169953064519  695687907                    3
# 14869       14869  1442949312063381006  695687907                    3
# 14870       14870  1442972095274896534  110938864                    2
# 14871       14871  1443457123327763296  452918929                  114
# 14872       14872  1443457546151071185  452918929                  114
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
# F) Sustitución de valores nulos con mediana (solo numéricas)
df_mediana= Jorge.nulos_mediana_df(df_csv)
df_mediana
#Identifica las columnas con datos numéricos.
#Calcula la mediana de cada columna.
#Reemplaza los valores nulos de esa columna con su mediana.
# Out:
#        Unnamed: 0                   id    host_id  host_listings_count  \
# 0               0                41339     180050                   26
# 1               1                55111     259711                    3
# 2               2                73828     259711                    3
# 3               3                87873     480980                    4
# 4               4                94701     505473                    1
# ...           ...                  ...        ...                  ...
# 14868       14868  1442944169953064519  695687907                    3
# 14869       14869  1442949312063381006  695687907                    3
# 14870       14870  1442972095274896534  110938864                    2
# 14871       14871  1443457123327763296  452918929                  114
# 14872       14872  1443457546151071185  452918929                  114
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
# G) Sustitución de valores nulos con constante (solo numéricas)
df_constante = Jorge.nulos_constante_df(df_csv, valor=0)  # aquí se puede cambiar el valor de la constante
df_constante
#Identifica las columnas con datos numéricos.
#Define un valor fijo (ejemplo: 0).
#Sustituye todos los valores nulos por esa constante.
# Out:
#        Unnamed: 0                   id    host_id  host_listings_count  \
# 0               0                41339     180050                   26
# 1               1                55111     259711                    3
# 2               2                73828     259711                    3
# 3               3                87873     480980                    4
# 4               4                94701     505473                    1
# ...           ...                  ...        ...                  ...
# 14868       14868  1442944169953064519  695687907                    3
# 14869       14869  1442949312063381006  695687907                    3
# 14870       14870  1442972095274896534  110938864                    2
# 14871       14871  1443457123327763296  452918929                  114
# 14872       14872  1443457546151071185  452918929                  114
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
# I) Identificación de valores nulos por columna y por dataframe
nulos_columna = df_csv.isnull().sum()
nulos_dataframe = df_csv.isnull().sum().sum()

print("Valores nulos por columna:\n", nulos_columna)
print("\nTotal de valores nulos en el DataFrame:", nulos_dataframe)

#Cuenta los nulos columna por columna (isnull().sum()).
#Calcula el total de nulos en todo el DataFrame (isnull().sum().sum()).
#Permite detectar qué variables necesitan limpieza y la magnitud del problema.
# Out:
# Valores nulos por columna:
#  Unnamed: 0                          0
# id                                  0
# listing_url                         0
# last_scraped                        0
# source                              0
# name                                0
# description                       348
# neighborhood_overview            6531
# picture_url                         0
# host_id                             0
# host_url                            0
# host_name                           0
# host_since                          0
# host_location                    5011
# host_about                       7056
# host_response_time               2233
# host_response_rate               2233
# host_acceptance_rate             1695
# host_is_superhost                 848
# host_thumbnail_url                  0
# host_picture_url                    0
# host_neighbourhood              13745
# host_listings_count                 0
# host_total_listings_count           0
# ...
